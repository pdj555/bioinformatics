# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1] Download Bioactivity Data (Concised version)**
#
# Chanin Nantasenamat
#
# [*'Data Professor' YouTube channel*](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 1**, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.
#
# Note for this Concised Version:
# * Redundant code cells were deleted.
# * Code cells for saving files to Google Drive has been deleted.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in /Users/prestonjones/anaconda3/lib/python3.10/site-packages (0.10.8)
# Requirement already satisfied: urllib3 in /Users/prestonjones/anaconda3/lib/python3.10/site-packages (from chembl_webresource_client) (1.26.14)
# Requirement already satisfied: requests>=2.18.4 in /Users/prestonjones/anaconda3/lib/python3.10/site-packages (from chembl_webresource_client) (2.31.0)
# Requirement already satisfied: requests-cache~=0.7.0 in /Users/prestonjones/anaconda3/lib/python3.10/site-packages (from chembl_webresource_client) (0.7.5)
# Requirement already satisfied: easydict in /Users/prestonjones/anaconda3/lib/python3.10/site-packages (from chembl_webresource_client) (1.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/prestonjones/anaconda3/lib/python3.10/site-packages (from requests>=2.18.4->chembl_webresource_client) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/prestonjones/anaconda3/lib/python3.10/site-packages (from requests>=2.18.4->chembl_webresource_client) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/prestonjones/anaconda3/lib/python3.10/site-packages (from requests>=2.18.4->chembl_webresource_client) (2023.5.7)
# Requirement already satisfied: attrs<22.0,>=21.2 in /Users/prestonjones/anaconda3/lib/python3.10/site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (21.4.0)
# Requirement already satisfied: itsdangerous>=2.0.1 in /Users/prestonjones/anaconda3/lib/python3.10/site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (2.0.1)
# Requirement already satisfied: pyyaml>=5.4 in /Users/prestonjones/anaconda3/lib/python3.10/site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (6.0)
# Requirement already satisfied: url-normalize<2.0,>=1.4 in /Users/prestonjones/anaconda3/lib/python3.10/site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (1.4.3)
# Requirement already satisfied: six in /Users/prestonjones/anaconda3/lib/python3.10/site-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.16.0)

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client
from utils import bioactivity_class

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Acetylcholinesterase**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('coronavirus')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
# 5                                                 []
# 6  [{'xref_id': 'P0C6U8', 'xref_name': None, 'xre...
# 7                                                 []
# 8  [{'xref_id': 'P0C6X7', 'xref_name': None, 'xre...
# 9                                                 []
#
#                                             organism  \
# 0                                        Coronavirus
# 1                                   SARS coronavirus
# 2                                 Feline coronavirus
# 3                                 Murine coronavirus
# 4                             Human coronavirus 229E
# 5                             Human coronavirus OC43
# 6                                   SARS coronavirus
# 7  Middle East respiratory syndrome-related coron...
# 8                                   SARS coronavirus
# 9    Severe acute respiratory syndrome coronavirus 2
#
#                                            pref_name  score  \
# 0                                        Coronavirus   17.0
# 1                                   SARS coronavirus   14.0
# 2                                 Feline coronavirus   14.0
# 3                                 Murine coronavirus   14.0
# 4                             Human coronavirus 229E   12.0
# 5                             Human coronavirus OC43   12.0
# 6                SARS coronavirus 3C-like proteinase   10.0
# 7  Middle East respiratory syndrome-related coron...    9.0
# 8                          Replicase polyprotein 1ab    4.0
# 9                          Replicase polyprotein 1ab    4.0
#
#    species_group_flag target_chembl_id  \
# 0               False     CHEMBL613732
# 1               False     CHEMBL612575
# 2               False     CHEMBL612744
# 3               False    CHEMBL5209664
# 4               False     CHEMBL613837
# 5               False    CHEMBL5209665
# 6               False       CHEMBL3927
# 7               False    CHEMBL4296578
# 8               False       CHEMBL5118
# 9               False    CHEMBL4523582
#
#                                    target_components     target_type   tax_id
# 0                                                 []        ORGANISM    11119
# 1                                                 []        ORGANISM   227859
# 2                                                 []        ORGANISM    12663
# 3                                                 []        ORGANISM   694005
# 4                                                 []        ORGANISM    11137
# 5                                                 []        ORGANISM    31631
# 6  [{'accession': 'P0C6U8', 'component_descriptio...  SINGLE PROTEIN   227859
# 7                                                 []        ORGANISM  1335626
# 8  [{'accession': 'P0C6X7', 'component_descriptio...  SINGLE PROTEIN   227859
# 9  [{'accession': 'P0DTD1', 'component_descriptio...  SINGLE PROTEIN  2697049

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Human Acetylcholinesterase* (first entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *Human Acetylcholinesterase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[6]
selected_target
# Out:
# 'CHEMBL3927'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Human Acetylcholinesterase* (CHEMBL220) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#     action_type activity_comment  activity_id activity_properties  \
# 0          None             None      1480935                  []
# 1          None             None      1480936                  []
# 2          None             None      1481061                  []
# 3          None             None      1481065                  []
# 4          None             None      1481066                  []
# ..          ...              ...          ...                 ...
# 100        None             None     12041507                  []
# 101        None             None     12041508                  []
# 102        None             None     12041509                  []
# 103        None             None     12041510                  []
# 104        None             None     12041511                  []
#
#     assay_chembl_id                                  assay_description  \
# 0      CHEMBL829584  In vitro inhibitory concentration against SARS...
# 1      CHEMBL829584  In vitro inhibitory concentration against SARS...
# 2      CHEMBL830868  In vitro inhibitory concentration against SARS...
# 3      CHEMBL829584  In vitro inhibitory concentration against SARS...
# 4      CHEMBL829584  In vitro inhibitory concentration against SARS...
# ..              ...                                                ...
# 100   CHEMBL2150313  Inhibition of SARS-CoV PLpro expressed in Esch...
# 101   CHEMBL2150313  Inhibition of SARS-CoV PLpro expressed in Esch...
# 102   CHEMBL2150313  Inhibition of SARS-CoV PLpro expressed in Esch...
# 103   CHEMBL2150313  Inhibition of SARS-CoV PLpro expressed in Esch...
# 104   CHEMBL2150313  Inhibition of SARS-CoV PLpro expressed in Esch...
#
#     assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0            B                    None                   None  BAO_0000190
# 1            B                    None                   None  BAO_0000190
# 2            B                    None                   None  BAO_0000190
# 3            B                    None                   None  BAO_0000190
# 4            B                    None                   None  BAO_0000190
# ..         ...                     ...                    ...          ...
# 100          B                    None                   None  BAO_0000190
# 101          B                    None                   None  BAO_0000190
# 102          B                    None                   None  BAO_0000190
# 103          B                    None                   None  BAO_0000190
# 104          B                    None                   None  BAO_0000190
#
#      ...   target_organism                     target_pref_name target_tax_id  \
# 0    ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 1    ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 2    ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 3    ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 4    ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# ..   ...               ...                                  ...           ...
# 100  ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 101  ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 102  ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 103  ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 104  ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
#
#     text_value  toid  type units    uo_units upper_value  value
# 0         None  None  IC50    uM  UO_0000065        None    7.2
# 1         None  None  IC50    uM  UO_0000065        None    9.4
# 2         None  None  IC50    uM  UO_0000065        None   13.5
# 3         None  None  IC50    uM  UO_0000065        None  13.11
# 4         None  None  IC50    uM  UO_0000065        None    2.0
# ..         ...   ...   ...   ...         ...         ...    ...
# 100       None  None  IC50    uM  UO_0000065        None   10.6
# 101       None  None  IC50    uM  UO_0000065        None   10.1
# 102       None  None  IC50    uM  UO_0000065        None   11.5
# 103       None  None  IC50    uM  UO_0000065        None   10.7
# 104       None  None  IC50    uM  UO_0000065        None   78.9
#
# [105 rows x 46 columns]

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('acetylcholinesterase_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
#     action_type activity_comment  activity_id activity_properties  \
# 0          None             None      1480935                  []
# 1          None             None      1480936                  []
# 2          None             None      1481061                  []
# 3          None             None      1481065                  []
# 4          None             None      1481066                  []
# ..          ...              ...          ...                 ...
# 100        None             None     12041507                  []
# 101        None             None     12041508                  []
# 102        None             None     12041509                  []
# 103        None             None     12041510                  []
# 104        None             None     12041511                  []
#
#     assay_chembl_id                                  assay_description  \
# 0      CHEMBL829584  In vitro inhibitory concentration against SARS...
# 1      CHEMBL829584  In vitro inhibitory concentration against SARS...
# 2      CHEMBL830868  In vitro inhibitory concentration against SARS...
# 3      CHEMBL829584  In vitro inhibitory concentration against SARS...
# 4      CHEMBL829584  In vitro inhibitory concentration against SARS...
# ..              ...                                                ...
# 100   CHEMBL2150313  Inhibition of SARS-CoV PLpro expressed in Esch...
# 101   CHEMBL2150313  Inhibition of SARS-CoV PLpro expressed in Esch...
# 102   CHEMBL2150313  Inhibition of SARS-CoV PLpro expressed in Esch...
# 103   CHEMBL2150313  Inhibition of SARS-CoV PLpro expressed in Esch...
# 104   CHEMBL2150313  Inhibition of SARS-CoV PLpro expressed in Esch...
#
#     assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0            B                    None                   None  BAO_0000190
# 1            B                    None                   None  BAO_0000190
# 2            B                    None                   None  BAO_0000190
# 3            B                    None                   None  BAO_0000190
# 4            B                    None                   None  BAO_0000190
# ..         ...                     ...                    ...          ...
# 100          B                    None                   None  BAO_0000190
# 101          B                    None                   None  BAO_0000190
# 102          B                    None                   None  BAO_0000190
# 103          B                    None                   None  BAO_0000190
# 104          B                    None                   None  BAO_0000190
#
#      ...   target_organism                     target_pref_name target_tax_id  \
# 0    ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 1    ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 2    ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 3    ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 4    ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# ..   ...               ...                                  ...           ...
# 100  ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 101  ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 102  ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 103  ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 104  ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
#
#     text_value  toid  type units    uo_units upper_value  value
# 0         None  None  IC50    uM  UO_0000065        None    7.2
# 1         None  None  IC50    uM  UO_0000065        None    9.4
# 2         None  None  IC50    uM  UO_0000065        None   13.5
# 3         None  None  IC50    uM  UO_0000065        None  13.11
# 4         None  None  IC50    uM  UO_0000065        None    2.0
# ..         ...   ...   ...   ...         ...         ...    ...
# 100       None  None  IC50    uM  UO_0000065        None   10.6
# 101       None  None  IC50    uM  UO_0000065        None   10.1
# 102       None  None  IC50    uM  UO_0000065        None   11.5
# 103       None  None  IC50    uM  UO_0000065        None   10.7
# 104       None  None  IC50    uM  UO_0000065        None   78.9
#
# [105 rows x 46 columns]

# %%
len(df2.canonical_smiles.unique())
# Out:
# 86

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#    action_type activity_comment  activity_id activity_properties  \
# 0         None             None      1480935                  []
# 1         None             None      1480936                  []
# 2         None             None      1481061                  []
# 3         None             None      1481065                  []
# 4         None             None      1481066                  []
# ..         ...              ...          ...                 ...
# 81        None             None     12040781                  []
# 82        None             None     12040782                  []
# 83        None             None     12040783                  []
# 84        None             None     12040784                  []
# 85        None             None     12040785                  []
#
#    assay_chembl_id                                  assay_description  \
# 0     CHEMBL829584  In vitro inhibitory concentration against SARS...
# 1     CHEMBL829584  In vitro inhibitory concentration against SARS...
# 2     CHEMBL830868  In vitro inhibitory concentration against SARS...
# 3     CHEMBL829584  In vitro inhibitory concentration against SARS...
# 4     CHEMBL829584  In vitro inhibitory concentration against SARS...
# ..             ...                                                ...
# 81   CHEMBL2149727  Inhibition of SARS-CoV 3CLpro expressed in Esc...
# 82   CHEMBL2149727  Inhibition of SARS-CoV 3CLpro expressed in Esc...
# 83   CHEMBL2149727  Inhibition of SARS-CoV 3CLpro expressed in Esc...
# 84   CHEMBL2149727  Inhibition of SARS-CoV 3CLpro expressed in Esc...
# 85   CHEMBL2149727  Inhibition of SARS-CoV 3CLpro expressed in Esc...
#
#    assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0           B                    None                   None  BAO_0000190
# 1           B                    None                   None  BAO_0000190
# 2           B                    None                   None  BAO_0000190
# 3           B                    None                   None  BAO_0000190
# 4           B                    None                   None  BAO_0000190
# ..        ...                     ...                    ...          ...
# 81          B                    None                   None  BAO_0000190
# 82          B                    None                   None  BAO_0000190
# 83          B                    None                   None  BAO_0000190
# 84          B                    None                   None  BAO_0000190
# 85          B                    None                   None  BAO_0000190
#
#     ...   target_organism                     target_pref_name target_tax_id  \
# 0   ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 1   ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 2   ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 3   ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 4   ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# ..  ...               ...                                  ...           ...
# 81  ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 82  ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 83  ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 84  ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 85  ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
#
#    text_value  toid  type units    uo_units upper_value  value
# 0        None  None  IC50    uM  UO_0000065        None    7.2
# 1        None  None  IC50    uM  UO_0000065        None    9.4
# 2        None  None  IC50    uM  UO_0000065        None   13.5
# 3        None  None  IC50    uM  UO_0000065        None  13.11
# 4        None  None  IC50    uM  UO_0000065        None    2.0
# ..        ...   ...   ...   ...         ...         ...    ...
# 81       None  None  IC50    uM  UO_0000065        None   21.1
# 82       None  None  IC50    uM  UO_0000065        None  226.7
# 83       None  None  IC50    uM  UO_0000065        None   38.7
# 84       None  None  IC50    uM  UO_0000065        None   14.4
# 85       None  None  IC50    uM  UO_0000065        None   21.1
#
# [86 rows x 46 columns]

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1        CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2        CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3        CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4        CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                ...                                                ...
# 81      CHEMBL2146517  COC(=O)[C@@]1(C)CCCc2c1ccc1c2C(=O)C(=O)c2c(C)c...
# 82       CHEMBL187460        C[C@H]1COC2=C1C(=O)C(=O)c1c2ccc2c1CCCC2(C)C
# 83       CHEMBL363535             Cc1coc2c1C(=O)C(=O)c1c-2ccc2c(C)cccc12
# 84       CHEMBL227075      Cc1cccc2c3c(ccc12)C1=C(C(=O)C3=O)[C@@H](C)CO1
# 85        CHEMBL45830             CC(C)C1=Cc2ccc3c(c2C(=O)C1=O)CCCC3(C)C
#
#    standard_value
# 0          7200.0
# 1          9400.0
# 2         13500.0
# 3         13110.0
# 4          2000.0
# ..            ...
# 81        21100.0
# 82       226700.0
# 83        38700.0
# 84        14400.0
# 85        21100.0
#
# [86 rows x 3 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv')

# %%
df5 = pd.concat([df4, bioactivity_class(df4.standard_value)], axis=1)

# %%
df5
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1        CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2        CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3        CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4        CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                ...                                                ...
# 81      CHEMBL2146517  COC(=O)[C@@]1(C)CCCc2c1ccc1c2C(=O)C(=O)c2c(C)c...
# 82       CHEMBL187460        C[C@H]1COC2=C1C(=O)C(=O)c1c2ccc2c1CCCC2(C)C
# 83       CHEMBL363535             Cc1coc2c1C(=O)C(=O)c1c-2ccc2c(C)cccc12
# 84       CHEMBL227075      Cc1cccc2c3c(ccc12)C1=C(C(=O)C3=O)[C@@H](C)CO1
# 85        CHEMBL45830             CC(C)C1=Cc2ccc3c(c2C(=O)C1=O)CCCC3(C)C
#
#     standard_value         class
# 0           7200.0  intermediate
# 1           9400.0  intermediate
# 2          13500.0      inactive
# 3          13110.0      inactive
# 4           2000.0  intermediate
# ..             ...           ...
# 81         21100.0      inactive
# 82        226700.0      inactive
# 83         38700.0      inactive
# 84         14400.0      inactive
# 85         21100.0      inactive
#
# [86 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('acetylcholinesterase_03_bioactivity_data_curated.csv', index=False)

# %%
! zip acetylcholinesterase.zip *.csv
# Out:
#   adding: acetylcholinesterase_01_bioactivity_data_raw.csv (deflated 89%)
#   adding: acetylcholinesterase_02_bioactivity_data_preprocessed.csv (deflated 72%)
#   adding: acetylcholinesterase_03_bioactivity_data_curated.csv (deflated 74%)
#   adding: acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv (deflated 76%)
#   adding: acetylcholinesterase_05_bioactivity_data_2class_pIC50.csv (deflated 76%)
#   adding: acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv (deflated 96%)
#   adding: acetylcholinesterase_07_bioactivity_data_2class_pIC50_pubchem_fp.csv (deflated 96%)

# %%
! ls -l
# Out:
# total 34704
# -rw-rw-r--@ 1 prestonjones  staff   105978 Aug  3 17:17 CDD_ML_Part_1_Acetylcholinesterase_Bioactivity_Data_Concised.ipynb
# -rw-rw-r--@ 1 prestonjones  staff   313244 May 22  2021 CDD_ML_Part_2_Acetylcholinesterase_Exploratory_Data_Analysis.ipynb
# -rw-rw-r--@ 1 prestonjones  staff   208719 May 22  2021 CDD_ML_Part_3_Acetylcholinesterase_Descriptor_Dataset_Preparation.ipynb
# -rw-rw-r--@ 1 prestonjones  staff   100076 May 22  2021 CDD_ML_Part_4_Acetylcholinesterase_Regression_Random_Forest.ipynb
# -rw-rw-r--@ 1 prestonjones  staff   230778 May 22  2021 CDD_ML_Part_5_Acetylcholinesterase_Compare_Regressors.ipynb
# -rw-r--r--  1 prestonjones  staff       17 Aug  3 17:12 README.md
# -rw-r--r--@ 1 prestonjones  staff   881129 Aug  3 17:59 acetylcholinesterase.zip
# -rw-rw-r--@ 1 prestonjones  staff    54457 Aug  3 17:21 acetylcholinesterase_01_bioactivity_data_raw.csv
# -rw-rw-r--@ 1 prestonjones  staff     5856 Aug  3 17:56 acetylcholinesterase_02_bioactivity_data_preprocessed.csv
# -rw-rw-r--@ 1 prestonjones  staff     6646 Aug  3 17:59 acetylcholinesterase_03_bioactivity_data_curated.csv
# -rw-rw-r--@ 1 prestonjones  staff   655414 May 22  2021 acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv
# -rw-rw-r--@ 1 prestonjones  staff   489152 May 22  2021 acetylcholinesterase_05_bioactivity_data_2class_pIC50.csv
# -rw-rw-r--@ 1 prestonjones  staff  8363909 May 22  2021 acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv
# -rw-rw-r--@ 1 prestonjones  staff  6323895 May 22  2021 acetylcholinesterase_07_bioactivity_data_2class_pIC50_pubchem_fp.csv

# %% [markdown]
# ---
